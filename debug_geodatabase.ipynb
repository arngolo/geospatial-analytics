# %%
import os
import ctypes
import sqlite3
from utils.geodatabase import create_change_detection_database, inspect_database, delete_records

# %%
# create database
spatialite_dll_path=r"C:\Program Files\QGIS 3.34.3\bin\mod_spatialite.dll"
create_change_detection_database("data/change_database.sqlite", spatialite_dll_path=spatialite_dll_path)
# Out:
# SpatiaLite database created: data/change_database.sqlite

# %%
# inspect database content
inspect_database("data/change_database.sqlite", spatialite_dll_path)
# Out:
# 3 layer(s): aoi, change_features, rasters
#
# --- aoi (1 row(s)) ---
# {'id': 1, 'name': 'mine_aoi', 'geometry': 'MULTIPOLYGON(((368505.01346 8637805.34074, 385151.709604 8637875.571213, 385089....'}
#
# --- change_features (10 row(s)) ---
# {'id': 1, 'date_before': '2023-08-12', 'date_after': '2023-09-02', 'method': 'SAM', 'area_m2': 1000.0, 'mean_change': None, 'geometry': 'MULTIPOLYGON(((369860 8638000, 369830 8638000, 369830 8638010, 369840 8638010, 3...'}
# {'id': 2, 'date_before': '2023-08-12', 'date_after': '2023-09-02', 'method': 'SAM', 'area_m2': 1700.0, 'mean_change': None, 'geometry': 'MULTIPOLYGON(((370580 8638080, 370570 8638080, 370570 8638060, 370560 8638060, 3...'}
# {'id': 3, 'date_before': '2023-08-12', 'date_after': '2023-09-02', 'method': 'SAM', 'area_m2': 1500.0, 'mean_change': None, 'geometry': 'MULTIPOLYGON(((370020 8639740, 370010 8639740, 370010 8639760, 370000 8639760, 3...'}
# {'id': 4, 'date_before': '2023-08-12', 'date_after': '2023-09-02', 'method': 'SAM', 'area_m2': 1800.0, 'mean_change': None, 'geometry': 'MULTIPOLYGON(((369590 8639880, 369600 8639880, 369600 8639890, 369630 8639890, 3...'}
# {'id': 5, 'date_before': '2023-08-12', 'date_after': '2023-09-02', 'method': 'SAM', 'area_m2': 1800.0, 'mean_change': None, 'geometry': 'MULTIPOLYGON(((369050 8640050, 369090 8640050, 369090 8640000, 369070 8640000, 3...'}
# {'id': 6, 'date_before': '2023-08-12', 'date_after': '2023-09-02', 'method': 'SAM', 'area_m2': 21200.0, 'mean_change': None, 'geometry': 'MULTIPOLYGON(((370220 8646600, 370250 8646600, 370250 8646610, 370240 8646610, 3...'}
# {'id': 7, 'date_before': '2023-08-12', 'date_after': '2023-09-02', 'method': 'SAM', 'area_m2': 25000.0, 'mean_change': None, 'geometry': 'MULTIPOLYGON(((369700 8646510, 369700 8646520, 369690 8646520, 369690 8646540, 3...'}
# {'id': 8, 'date_before': '2023-08-12', 'date_after': '2023-09-02', 'method': 'SAM', 'area_m2': 1700.0, 'mean_change': None, 'geometry': 'MULTIPOLYGON(((370220 8646690, 370210 8646690, 370210 8646720, 370200 8646720, 3...'}
# {'id': 9, 'date_before': '2023-08-12', 'date_after': '2023-09-02', 'method': 'SAM', 'area_m2': 3200.0, 'mean_change': None, 'geometry': 'MULTIPOLYGON(((370370 8646740, 370360 8646740, 370360 8646730, 370370 8646730, 3...'}
# {'id': 10, 'date_before': '2023-08-12', 'date_after': '2023-09-02', 'method': 'SAM', 'area_m2': 4400.0, 'mean_change': None, 'geometry': 'MULTIPOLYGON(((370490 8646800, 370480 8646800, 370480 8646790, 370500 8646790, 3...'}
#
# --- rasters (9 row(s)) ---
# {'id': 1, 'acquisition_date': 'unknown', 'raster_type': 'binary_cd_auto_otsu_cva', 'file_path': 'data/processed/binary_cd_auto_otsu_cva.tif'}
# {'id': 2, 'acquisition_date': 'unknown', 'raster_type': 'binary_cd_threshold_98_sam', 'file_path': 'data/processed/binary_cd_threshold_98_sam.tif'}
# {'id': 3, 'acquisition_date': 'unknown', 'raster_type': 'change', 'file_path': 'data/processed/change.tif'}
# {'id': 4, 'acquisition_date': 'unknown', 'raster_type': 'change_probability', 'file_path': 'data/processed/change_probability.tif'}
# {'id': 5, 'acquisition_date': 'unknown', 'raster_type': 'change_probability_sam', 'file_path': 'data/processed/change_probability_sam.tif'}
# {'id': 6, 'acquisition_date': 'unknown', 'raster_type': 'change_sam', 'file_path': 'data/processed/change_sam.tif'}
# {'id': 7, 'acquisition_date': 'unknown', 'raster_type': 'geotiff_hist_match', 'file_path': 'data/processed/geotiff_hist_match.tif'}
# {'id': 8, 'acquisition_date': 'unknown', 'raster_type': 'sentinel2_20230812_RGB', 'file_path': 'data/processed/sentinel2_20230812_RGB.tif'}
# {'id': 9, 'acquisition_date': 'unknown', 'raster_type': 'sentinel2_20230902_RGB', 'file_path': 'data/processed/sentinel2_20230902_RGB.tif'}

# %%
# delete records

# remove one row by id
delete_records("data/change_database.sqlite", spatialite_dll_path, "rasters", id=13)
# Out:
# Removed all rows from rasters (9 deleted)

# %%
# # remove by field value
delete_records("data/change_database.sqlite", spatialite_dll_path, "rasters", where={"raster_type": "change_sam"})

# %%
delete_records("data/change_database.sqlite", spatialite_dll_path, "change_features", where={"method": "SAM"})

# %%
# # # remove everything in a table
delete_records("data/change_database.sqlite", spatialite_dll_path, "rasters", remove_all=True)
